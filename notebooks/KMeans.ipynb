# %%
import pandas as pd # import for dataframe handle
import numpy as np # import for math and array operations
import matplotlib.pyplot as plt # import for visual representation
#import seaborn as sns # import for visual representation

import re
import string
from nltk.corpus import stopwords 
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

from bs4 import BeautifulSoup
import requests

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv("../raw_data/clean_df.csv")
df.head()
# Out:
#                                                  url  \
# 0    https://store.steampowered.com/app/379720/DOOM/
# 1  https://store.steampowered.com/app/578080/PLAY...
# 2  https://store.steampowered.com/app/637090/BATT...
# 3    https://store.steampowered.com/app/221100/DayZ/
# 4  https://store.steampowered.com/app/8500/EVE_On...
#
#                             name            developer  \
# 0                           DOOM          id Software
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS     PUBG Corporation
# 2                     BATTLETECH  Harebrained Schemes
# 3                           DayZ  Bohemia Interactive
# 4                     EVE Online                  CCP
#
#                                                 tags  \
# 0  fps gore action demon shooter first person gre...
# 1  survival shooter multiplayer battle royale pvp...
# 2  mechs strategy turn based turn based tactic sc...
# 3  survival zombie open world multiplayer pvp mas...
# 4  space massively multiplayer sci fi sandbox mmo...
#
#                                            languages  \
# 0  english french italian german spanish spain ja...
# 1  english korean simplified chinese french germa...
# 2                      english french german russian
# 3  english french italian german spanish spain cz...
# 4                      english german russian french
#
#                                                genre  \
# 0                                             action
# 1             action adventure massively multiplayer
# 2                          action adventure strategy
# 3             action adventure massively multiplayer
# 4  action free play massively multiplayer rpg str...
#
#                                     game_description  mature_content   price  \
# 0  game developed id software studio pioneered fi...               0  17.991
# 1  game playerunknown battleground battle royale ...               1  26.991
# 2  game original battletech mechwarrior creator j...               0  35.991
# 3  game post soviet country chernarus struck unkn...               0  40.491
# 4                                               game               0     NaN
#
#            reviews                 date  achievements               op_sys  \
# 0    Very Positive  2016-05-12 00:00:00           1.0              windows
# 1            Mixed  2017-12-21 00:00:00           1.0              windows
# 2  Mostly Positive  2018-04-24 00:00:00           1.0  windows macOS Linux
# 3            Mixed  2018-12-13 00:00:00           0.0              windows
# 4  Mostly Positive  2003-05-06 00:00:00           0.0        windows macOS
#
#                                             metadata
# 0  soundtrack multiplayer singleplayer fast paced...
# 1  multiplayer shooter action online person team ...
# 2  tactic sci fi turn based mechs strategy turn b...
# 3  access simulation fps post apocalyptic surviva...
# 4  multiplayer rpg strategy play economy strategy...

# %%
def clean (text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, ' ') # Remove Punctuation
    lowercased = text.lower() # Lower Case
    tokenized = word_tokenize(lowercased) # Tokenize
    words_only = [word for word in tokenized if word.isalpha()] # Remove numbers
    stop_words = set(stopwords.words('english')) # Make stopword list
    without_stopwords = [word for word in words_only if not word in stop_words] # Remove Stop Words
    lemma=WordNetLemmatizer() # Initiate Lemmatizer
    lemmatized = [lemma.lemmatize(word) for word in without_stopwords] # Lemmatize
    return " ".join(lemmatized)

# %%
clean_df=df.assign(clean_description=lambda x: x.game_description.astype('str').apply(clean))
clean_df.head()
# Out:
#                                                  url  \
# 0    https://store.steampowered.com/app/379720/DOOM/
# 1  https://store.steampowered.com/app/578080/PLAY...
# 2  https://store.steampowered.com/app/637090/BATT...
# 3    https://store.steampowered.com/app/221100/DayZ/
# 4  https://store.steampowered.com/app/8500/EVE_On...
#
#                             name            developer  \
# 0                           DOOM          id Software
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS     PUBG Corporation
# 2                     BATTLETECH  Harebrained Schemes
# 3                           DayZ  Bohemia Interactive
# 4                     EVE Online                  CCP
#
#                                                 tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                            languages  \
# 0  English,French,Italian,German,Spanish - Spain,...
# 1  English,Korean,Simplified Chinese,French,Germa...
# 2                      English,French,German,Russian
# 3  English,French,Italian,German,Spanish - Spain,...
# 4                      English,German,Russian,French
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description  mature_content   price  \
# 0   About This Game Developed by id software, the...               0  17.991
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...               1  26.991
# 2   About This Game  From original BATTLETECH/Mec...               0  35.991
# 3   About This Game The post-soviet country of Ch...               0  40.491
# 4                                  About This Game                 0     NaN
#
#            reviews                 date  achievements               op_sys  \
# 0    Very Positive  2016-05-12 00:00:00           1.0              windows
# 1            Mixed  2017-12-21 00:00:00           1.0              windows
# 2  Mostly Positive  2018-04-24 00:00:00           1.0  windows macOS Linux
# 3            Mixed  2018-12-13 00:00:00           0.0              windows
# 4  Mostly Positive  2003-05-06 00:00:00           0.0        windows macOS
#
#                                    clean_description
# 0  game developed id software studio pioneered fi...
# 1  game playerunknown battleground battle royale ...
# 2  game original battletech mechwarrior creator j...
# 3  game post soviet country chernarus struck unkn...
# 4                                               game

# %%
# Tuned TFidfvectorizer
vec = TfidfVectorizer(min_df = 0.04,ngram_range=(1,2)).fit(clean_df.clean_description)

vectors = vec.transform(clean_df.clean_description) # Transform text to vectors
sum_tfidf = vectors.sum(axis=0) # Sum of tfidf weighting by word
tfidf_list = [(word, sum_tfidf[0, idx]) for word, idx in vec.vocabulary_.items()]  # Get the word and associated weight
sorted_tfidf_list =sorted(tfidf_list, key = lambda x: x[1], reverse=True)  # Sort
sorted_tfidf_list
# Out:
# [('game', 2845.290446835472),
#  ('world', 1181.8949337513448),
#  ('level', 1153.3183669875718),
#  ('player', 1130.0493535974222),
#  ('new', 1062.0506699517246),
#  ('play', 909.2270206751421),
#  ('time', 856.1294658743665),
#  ('mode', 849.6906607048571),
#  ('enemy', 837.3558933645428),
#  ('puzzle', 825.2479789138846),
#  ('feature', 812.003801828686),
#  ('one', 794.8166203826302),
#  ('story', 770.9994662114602),
#  ('different', 759.546136325372),
#  ('character', 745.2977936933515),
#  ('find', 701.191383880587),
#  ('get', 690.4062216544905),
#  ('weapon', 682.8067354946745),
#  ('way', 663.4956241555884),
#  ('unique', 661.8335478629541),
#  ('battle', 653.2460131621135),
#  ('take', 646.2192360097004),
#  ('experience', 643.7232608246675),
#  ('adventure', 621.8772377314147),
#  ('make', 619.9135545000145),
#  ('use', 610.8673657189966),
#  ('gameplay', 577.1873052197064),
#  ('like', 575.1902800059488),
#  ('system', 560.2746193066391),
#  ('life', 549.5986516084688),
#  ('action', 546.9119723914426),
#  ('control', 538.1867960241799),
#  ('friend', 530.0338962042586),
#  ('skill', 524.7604554386415),
#  ('fight', 516.4072884432532),
#  ('challenge', 502.8469364084545),
#  ('help', 494.28223565720873),
#  ('explore', 491.83170171676284),
#  ('power', 486.43099804794986),
#  ('need', 475.9490281839871),
#  ('based', 472.84050817456165),
#  ('first', 471.9618155093091),
#  ('vr', 471.66519905203575),
#  ('encounter', 160.73604947659638),
#  ('avoid', 160.09294553000652),
#  ('real time', 160.0800438962638),
#  ('exploration', 160.07039807070754),
#  ('game game', 159.92557093284242),
#  ('bit', 159.5827086837698),
#  ('built', 159.5336318507291),
#  ('large', 159.29604892220578),
#  ('wall', 159.21314728937963),
#  ('step', 158.4487719437169),
#  ('customize', 158.03626119267236),
#  ('guide', 157.80479940911158),
#  ('group', 157.67420485854984),
#  ('command', 157.52881860230232),
#  ('uncover', 156.8688276170011),
#  ('follow', 156.61244992083874),
#  ('others', 156.60127548552546),
#  ('interesting', 156.35173085699145),
#  ('increase', 155.48975155880288),
#  ('rule', 155.44467436753766),
#  ('return', 155.3707653118468),
#  ('release', 155.34700502355162),
#  ('plan', 155.0379057298861),
#  ('extra', 154.5100918712218),
#  ('begin', 154.16245084482642),
#  ('soon', 153.8662632178159),
#  ('share', 153.84585304703074),
#  ('yet', 153.456367886582),
#  ('decision', 153.31121155668282),
#  ('random', 153.00862922950168),
#  ('might', 152.75717506682565),
#  ('manage', 151.5969494497079),
#  ('far', 151.58493069038582),
#  ('perfect', 151.24277780375783),
#  ('immersive', 150.88828451393542),
#  ('dozen', 150.75047840022341),
#  ('hundred', 150.43231386010848),
#  ('five', 149.8987351679171),
#  ('custom', 149.87560582864705),
#  ('mean', 149.80163283309648),
#  ('form', 149.75866667220203),
#  ('final', 148.998119418489),
#  ('early', 148.4620560808818),
#  ('range', 148.1427941123502),
#  ('break', 147.59563738547345),
#  ('throughout', 147.36866655218606),
#  ('found', 146.777028254195),
#  ('modern', 146.24833672856576),
#  ('note', 146.00798615605976),
#  ('ground', 145.73347700857423),
#  ('chance', 145.65999940733857),
#  ('enter', 145.63904880290565),
#  ('playable', 145.57553935606515),
#  ('intense', 144.84565957255046),
#  ('advanced', 144.4801176613741),
#  ('improve', 144.45203672994845),
#  ('update', 144.09442010865368),
#  ('known', 144.0936530447277),
#  ('completely', 143.1041099118193),
#  ('stay', 142.70777286508925),
#  ('rich', 142.39446787003644),
#  ('detailed', 141.96333184039221),
#  ('living', 141.57788312003427),
#  ('combine', 139.89075327037077),
#  ('sure', 139.04100801218146),
#  ('coming', 138.92367529944164),
#  ('trying', 138.8290316271566),
#  ('victory', 138.47319645993662),
#  ('played', 137.84188819880683),
#  ('combination', 136.56486285966767),
#  ('additional', 135.98717572183662),
#  ('name', 135.70546780397967),
#  ('developed', 133.96370951986174),
#  ('depth', 132.46510612209343),
#  ('allow', 131.85077092678313),
#  ('taking', 131.22871665613334),
#  ('quickly', 131.01526414182666),
#  ('important', 125.6064652768768),
#  ('entire', 120.66552700208022)]

# %%
X_proj = pd.DataFrame(vectors.toarray(), index=clean_df.name.tolist())

# %%
km = KMeans(n_clusters=50)
km.fit(X_proj)
# Out:
# KMeans(n_clusters=50)

# %%
km.cluster_centers_.shape
# Out:
# (50, 485)

# %%
km.cluster_centers_.shape
# Out:
# (50, 485)

# %%
labels = km.labels_
clustered_df = pd.DataFrame(data=labels, index=clean_df.name.tolist(), columns = ['cluster'])

# %%
clustered_df[clustered_df['cluster'] == 7]
# Out:
#                                 cluster
# Beat Saber                            7
# Rocksmith™                            7
# BOXVR                                 7
# Mixcraft 8 Home Studio                7
# Beat Hazard 2                         7
# ...                                 ...
# Beat Miner                            7
# Rhythm Doctor                         7
# Muse Dash                             7
# Zima uhodi!                           7
# ATONE: Heart of the Elder Tree        7
#
# [296 rows x 1 columns]

# %%
clustered_df.value_counts()
# Out:
# cluster
# 18         1325
# 8          1129
# 9           950
# 19          890
# 16          889
# 23          876
# 49          864
# 4           767
# 24          748
# 27          707
# 37          653
# 35          643
# 48          637
# 3           623
# 0           620
# 39          616
# 12          594
# 46          524
# 30          498
# 47          496
# 29          457
# 15          442
# 20          430
# 25          423
# 10          413
# 43          389
# 2           379
# 41          370
# 40          359
# 33          352
# 45          349
# 28          348
# 34          346
# 6           336
# 21          330
# 5           314
# 26          307
# 11          304
# 7           296
# 44          293
# 42          282
# 32          276
# 38          271
# 22          258
# 17          229
# 14          226
# 13          198
# 36          190
# 1           188
# 31          163
# dtype: int64

# %%
# inertias = []
# ks = range(1,100)
# for k in ks:
#     km_test = KMeans(n_clusters=k).fit(X_proj)
#     inertias.append(km_test.inertia_)
# plt.plot(ks, inertias)
# plt.xlabel('k cluster number')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 177, in where
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 177, in where
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 177, in where
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 177, in where
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 177, in where
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 177, in where
# KeyboardInterrupt:

# %% [markdown]
# ## Testing different n_gram values

# %%
# Tuned TFidfvectorizer with different n_gram values
vec2 = TfidfVectorizer(min_df = 0.05,ngram_range=(2,2)).fit(clean_df.clean_description)

vectors2 = vec2.transform(clean_df.clean_description) # Transform text to vectors
sum_tfidf2 = vectors2.sum(axis=0) # Sum of tfidf weighting by word
tfidf_list2 = [(word, sum_tfidf2[0, idx]) for word, idx in vec2.vocabulary_.items()]  # Get the word and associated weight
sorted_tfidf_list2 =sorted(tfidf_list2, key = lambda x: x[1], reverse=True)  # Sort
sorted_tfidf_list2
# Out:
# [('key feature', 2356.0997995678854),
#  ('game mode', 1431.248727608694),
#  ('game feature', 1334.6418452150015),
#  ('single player', 1241.3912167979283),
#  ('game play', 1164.1713143197808),
#  ('fast paced', 1079.1122243844788)]

# %%
X_proj2 = pd.DataFrame(vectors2.toarray(), index=clean_df.name.tolist())

# %%
km2 = KMeans(n_clusters=50)
km2.fit(X_proj2)
# Out:
# KMeans(n_clusters=50)

# %%
km2.cluster_centers_.shape
# Out:
# (50, 6)

# %%
labels2 = km2.labels_
clustered_df2 = pd.DataFrame(data=labels2, index=clean_df.name.tolist(), columns = ['cluster'])

# %%
clustered_df2[clustered_df2['cluster'] == 7]
# Out:
#                                      cluster
# BioShock Infinite                          7
# Killing Floor 2                            7
# World War 3                                7
# Insurgency: Sandstorm                      7
# BATTALION 1944                             7
# ...                                      ...
# Juggly                                     7
# Stack Gun Heroes                           7
# Killer Clowns                              7
# Land of Chaos Online II: Revolution        7
# Overduty VR: Battle Royale                 7
#
# [107 rows x 1 columns]

# %%
clustered_df2.value_counts()
# Out:
# cluster
# 0          16651
# 1           1962
# 3           1083
# 2            936
# 4            872
# 5            780
# 6            710
# 8            141
# 9            119
# 7            107
# 17            84
# 11            79
# 13            69
# 15            68
# 10            61
# 18            60
# 12            59
# 14            59
# 16            55
# 20            53
# 21            47
# 19            41
# 29            35
# 22            34
# 39            31
# 23            29
# 32            28
# 24            24
# 34            24
# 45            24
# 36            22
# 27            21
# 41            18
# 25            17
# 33            16
# 47            16
# 44            15
# 26            15
# 38            13
# 30            11
# 48            11
# 35             9
# 31             9
# 42             9
# 49             8
# 40             7
# 28             7
# 37             6
# 43             6
# 46             6
# dtype: int64

# %% [markdown]
# ### testing clusters

# %%
vec3 = TfidfVectorizer(min_df = 0.05,ngram_range=(1,2)).fit(df.game_description)

vectors3 = vec3.transform(df.game_description) # Transform text to vectors
sum_tfidf3 = vectors3.sum(axis=0) # Sum of tfidf weighting by word
tfidf_list3 = [(word, sum_tfidf3[0, idx]) for word, idx in vec3.vocabulary_.items()]  # Get the word and associated weight
sorted_tfidf_list3 =sorted(tfidf_list2, key = lambda x: x[1], reverse=True)  # Sort
sorted_tfidf_list3
# Out:
# [('key feature', 2356.0997995678854),
#  ('game mode', 1431.248727608694),
#  ('game feature', 1334.6418452150015),
#  ('single player', 1241.3912167979283),
#  ('game play', 1164.1713143197808),
#  ('fast paced', 1079.1122243844788)]

# %%
X_proj3 = pd.DataFrame(vectors3.toarray(), index=df.name.tolist())

# %%
km3 = KMeans(n_clusters=70)
km3.fit(X_proj3)
# Out:
# KMeans(n_clusters=70)

# %%
km3.cluster_centers_.shape
# Out:
# (70, 350)

# %%
labels3 = km3.labels_
clustered_df3 = pd.DataFrame(data=labels3, index=df.name.tolist(), columns = ['cluster'])

# %%
clustered_df3[clustered_df3['cluster'] == 7]
# Out:
#                                    cluster
# EVE Online                               7
# Ring of Elysium                          7
# Neverwinter                              7
# Crypt of the NecroDancer                 7
# Star Trek Online                         7
# ...                                    ...
# Mr Dirt Poor                             7
# 東方輝針城 〜 Double Dealing Character.        7
# 東方神霊廟 〜 Ten Desires.                     7
# Вкудахте - Симулятор Соцсети             7
# Indivisible                              7
#
# [198 rows x 1 columns]

# %%
clustered_df3.value_counts()
# Out:
# cluster
# 54         1196
# 21          907
# 2           682
# 64          548
# 40          547
#            ...
# 42          191
# 3           190
# 63          178
# 48          176
# 7           167
# Length: 70, dtype: int64

# %%
clustered_df3.value_counts()
# Out:
# cluster
# 39         727
# 50         692
# 0          649
# 2          635
# 13         589
#           ...
# 68         193
# 41         186
# 27         182
# 53         180
# 30         164
# Length: 70, dtype: int64

# %%
pd.set_option('display.max_rows', 300)

# %%
clustered_df3[clustered_df3['cluster']==55]
# Out:
#                                        cluster
# DOOM                                        55
# Call of Duty®: Black Ops                    55
# Grand Theft Auto IV: Complete Edition       55
# Men of War: Assault Squad 2                 55
# Stick Fight: The Game                       55
# ...                                        ...
# Mask of Fury                                55
# SUPERVERSE                                  55
# Bullet Force                                55
# HyperDot                                    55
# Aether Drift                                55
#
# [332 rows x 1 columns]
